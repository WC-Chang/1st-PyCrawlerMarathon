# %%
# 「File I/O」與「xmltodict」，前者為字串，後者為類似dict元素
# 讀檔案
fh = open("./data/64_72hr_CH.xml", "r",encoding="utf-8")
xml = fh.read()
fh.close()

print(xml)
# Out:
#             <elementValue>
#               <value>16</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2019-11-29T21:00:00+08:00</dataTime>
#             <elementValue>
#               <value>16</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2019-11-30T00:00:00+08:00</dataTime>
#             <elementValue>
#               <value>15</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2019-11-30T03:00:00+08:00</dataTime>
#             <elementValue>
#               <value>14</value>
#               <measures>攝氏度</measures>
#             </elementValue>
#           </time>
#           <time>
#             <dataTime>2019-11-30T06:00:00+08:00</dataTime>
#             <elementValue>
#               <value>14</value>
# ...

# %%
# 解析檔案內容
import sys 
sys.path.append('c://users/user/appdata/local/programs/python/python38-32/lib/site-packages')
import xmltodict

with open("./data/64_72hr_CH.xml","r",encoding="utf-8") as df:
    df_str = df.read()
    x = dict(xmltodict.parse(df_str))
    print(x)
# Out:
# alue', '<= 1'), ('measures', '蒲福風級')])])]), OrderedDict([('dataTime', '2019-11-30T03:00:00+08:00'), ('elementValue', [OrderedDict([('value', '1'), ('measures', '公尺/秒')]), OrderedDict([('value', '<= 1'), ('measures', '蒲福風級')])])]), OrderedDict([('dataTime', '2019-11-30T06:00:00+08:00'), ('elementValue', [OrderedDict([('value', '1'), ('measures', '公尺/秒')]), OrderedDict([('value', '<= 1'), ('measures', '蒲福風級')])])]), OrderedDict([('dataTime', '2019-11-30T09:00:00+08:00'), ('elementValue', [OrderedDict([('value', '1'), ('measures', '公尺/秒')]), OrderedDict([('value', '<= 1'), ('measures', '蒲福風級')])])]), OrderedDict([('dataTime', '2019-11-30T12:00:00+08:00'), ('elementValue', [OrderedDict([('value', '1'), ('measures', '公尺/秒')]), OrderedDict([('value', '<= 1'), ('measures', '蒲福風級')])])]), OrderedDict([('dataTime', '2019-11-30T15:00:00+08:00'), ('elementValue', [OrderedDict([('value', '1'), ('measures', '公尺/秒')]), OrderedDict([('value', '<= 1'), ('measures', '蒲福風級')])])])])]), OrderedDict([('
# ...

# %%
# 下載檔案
import urllib.request
import zipfile

res = "http://opendata.cwb.gov.tw/govdownload?dataid=F-D0047-093&authorizationkey=rdec-key-123-45678-011121314"
urllib.request.urlretrieve(res, "./data/exampleDay3.zip")
f = zipfile.ZipFile('./data/exampleDay3.zip')
f.extractall('./data')

# %%
import os, sys

# 打开文件
dirs = os.listdir( './data' )

# 输出所有文件和文件夹
for file in dirs:
    print(file)
# Out:
# 09007_72hr_CH.xml
# 09007_72hr_EN.xml
# 09007_Week24_CH.xml
# 09007_Week24_EN.xml
# 09007_Weekday_CH.xml
# 09007_Weekday_EN.xml
# 09020_72hr_CH.xml
# 09020_72hr_EN.xml
# 09020_Week24_CH.xml
# 09020_Week24_EN.xml
# 09020_Weekday_CH.xml
# 09020_Weekday_EN.xml
# 10002_72hr_CH.xml
# 10002_72hr_EN.xml
# 10002_Week24_CH.xml
# 10002_Week24_EN.xml
# 10002_Weekday_CH.xml
# 10002_Weekday_EN.xml
# 10004_72hr_CH.xml
# 10004_72hr_EN.xml
# 10004_Week24_CH.xml
# 10004_Week24_EN.xml
# 10004_Weekday_CH.xml
# 10004_Weekday_EN.xml
# 10005_72hr_CH.xml
# 10005_72hr_EN.xml
# 10005_Week24_CH.xml
# 10005_Week24_EN.xml
# 10005_Weekday_CH.xml
# 10005_Weekday_EN.xml
# 10007_72hr_CH.xml
# 10007_72hr_EN.xml
# 10007_Week24_CH.xml
# 10007_Week24_EN.xml
# 10007_Weekday_CH.xml
# 10007_Weekday_EN.xml
# 10008_72hr_CH.xml
# 10008_72hr_EN.xml
# 10008_Week24_CH.xml
# 10008_Week24_EN.xml
# 10008_Weekday_CH.xml
# 10008_Weekday_EN.xml
# 10009_72hr_CH.xml
# 10009_72hr_EN.xml
# 10009_Week24_CH.xml
# 10009_Week24_EN.xml
# ...

# %%
# 1. 請問高雄市有多少地區有溫度資料？
import xmltodict
with open('./data/64_72hr_CH.xml', 'r',encoding="utf-8") as fd:
    fd_str = fd.read()
    doc = dict(xmltodict.parse(fd_str))
    doc['cwbopendata']['dataset']
    locations = doc['cwbopendata']['dataset']['locations']['location']
    i = 0
    for location in locations:
        if 'weatherElement' in location:
            i += 1
    print(i)
# Out:
# 38

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
import xmltodict
with open('./data/64_72hr_CH.xml', 'r',encoding="utf-8") as fd:
    fd_str = fd.read()
    doc = dict(xmltodict.parse(fd_str))
    doc['cwbopendata']['dataset']
    locations = doc['cwbopendata']['dataset']['locations']['location']
    data_dict = {location['locationName']: location['weatherElement'][0]['time'][0]['elementValue']['value'] + '度' for location in locations}
    print(data_dict)
# Out:
# {'鹽埕區': '25度', '鼓山區': '25度', '左營區': '25度', '楠梓區': '25度', '三民區': '25度', '新興區': '26度', '前金區': '25度', '苓雅區': '26度', '前鎮區': '25度', '旗津區': '24度', '小港區': '26度', '鳳山區': '26度', '林園區': '26度', '大寮區': '26度', '大樹區': '26度', '大社區': '25度', '仁武區': '25度', '鳥松區': '25度', '岡山區': '25度', '橋頭區': '25度', '燕巢區': '25度', '田寮區': '23度', '阿蓮區': '23度', '路竹區': '25度', '湖內區': '24度', '茄萣區': '23度', '永安區': '24度', '彌陀區': '24度', '梓官區': '24度', '旗山區': '24度', '美濃區': '25度', '六龜區': '22度', '甲仙區': '21度', '杉林區': '25度', '內門區': '23度', '茂林區': '23度', '桃源區': '20度', '那瑪夏區': '18度'}

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
import sys 
sys.path.append('c://users/user/appdata/local/programs/python/python38-32/lib/site-packages')
import xmltodict
with open('./data/64_72hr_CH.xml', 'r',encoding="utf-8") as fd:
    fd_str = fd.read()
    doc = dict(xmltodict.parse(fd_str))
    doc['cwbopendata']['dataset']
    locations = doc['cwbopendata']['dataset']['locations']['location'][0]

    data_dict = {locations['locationName']: [{data['dataTime']: data['elementValue']['value'] + '度'} for data in locations['weatherElement'][0]['time']]}
    print(data_dict)
# Out:
# {'鹽埕區': [{'2019-11-27T18:00:00+08:00': '25度'}, {'2019-11-27T21:00:00+08:00': '23度'}, {'2019-11-28T00:00:00+08:00': '22度'}, {'2019-11-28T03:00:00+08:00': '21度'}, {'2019-11-28T06:00:00+08:00': '20度'}, {'2019-11-28T09:00:00+08:00': '23度'}, {'2019-11-28T12:00:00+08:00': '27度'}, {'2019-11-28T15:00:00+08:00': '27度'}, {'2019-11-28T18:00:00+08:00': '24度'}, {'2019-11-28T21:00:00+08:00': '23度'}, {'2019-11-29T00:00:00+08:00': '21度'}, {'2019-11-29T03:00:00+08:00': '20度'}, {'2019-11-29T06:00:00+08:00': '19度'}, {'2019-11-29T09:00:00+08:00': '21度'}, {'2019-11-29T12:00:00+08:00': '24度'}, {'2019-11-29T15:00:00+08:00': '25度'}, {'2019-11-29T18:00:00+08:00': '23度'}, {'2019-11-29T21:00:00+08:00': '22度'}, {'2019-11-30T00:00:00+08:00': '21度'}, {'2019-11-30T03:00:00+08:00': '21度'}, {'2019-11-30T06:00:00+08:00': '20度'}, {'2019-11-30T09:00:00+08:00': '22度'}, {'2019-11-30T12:00:00+08:00': '26度'}, {'2019-11-30T15:00:00+08:00': '26度'}]}
